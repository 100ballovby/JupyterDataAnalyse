# %%
# рисуем графики сразу же
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot') # будут красивые графички
plt.rcParams['figure.figsize'] = (15, 5) # Размер картинки, которую выведут

# %%
ds = pd.read_csv('datasets/311-service-requests.csv', low_memory=False)

# %%
ds[:3] # ограничиваю вывод записей
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department          Illegal Parking
# 2  New York City Police Department       Noise - Commercial
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# 1  Commercial Overnight Parking      Street/Sidewalk        11378
# 2              Loud Music/Party  Club/Bar/Restaurant        10032
#
#    Incident Address  ... Bridge Highway Name Bridge Highway Direction  \
# 0  90-03 169 STREET  ...                 NaN                      NaN
# ...

# %%
ds['Complaint Type'][:5]  # вывести 5 записей по ключу 'Complaint type'
# Out:
# 0    Noise - Street/Sidewalk
# 1            Illegal Parking
# 2         Noise - Commercial
# 3            Noise - Vehicle
# 4                     Rodent
# Name: Complaint Type, dtype: object

# %%
ds[['Complaint Type', 'Street Name']][:5]
# Out:
#             Complaint Type      Street Name
# 0  Noise - Street/Sidewalk       169 STREET
# 1          Illegal Parking        58 AVENUE
# 2       Noise - Commercial         BROADWAY
# 3          Noise - Vehicle   WEST 72 STREET
# 4                   Rodent  WEST 124 STREET

# %%
popular_complaints = ds['Complaint Type'].value_counts()[:11]  # вывести, почему чаще всего вызывали
popular_complaints.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
popular_agency = ds['Agency Name'].value_counts()[:11]
popular_agency.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import numpy as np

pd.options.display.max_rows = 10
# отображать все выводы не больше 10 строк
weather_ds = pd.read_csv('datasets/weather_2012.csv', index_col='Date/Time')

weather_ds['Temp (C)'].plot(figsize=(30, 10))
# Out:
# <AxesSubplot:xlabel='Date/Time'>
